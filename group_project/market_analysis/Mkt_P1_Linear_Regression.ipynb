# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# Load and preprocess data
def load_and_prepare_data(file_path):
    # Load data with error handling for missing values
    df = pd.read_csv(file_path, 
                    parse_dates=['date'], 
                    na_values=['#N/A', 'N/A', 'NaN'])
    
    # Create lagged sentiment score (t-1)
    df['sentiment_lag1'] = df['sentiment_score'].shift(1)
    
    # Drop missing values
    df = df.dropna(subset=['sentiment_lag1', 'yield', 'binary'])
    
    return df

# Run regression for multiple assets
def run_regressions(df, dependent_vars):
    results = {}
    
    for asset in dependent_vars:
        # Prepare independent variables
        X = df[['sentiment_lag1', 'yield', 'binary']]
        X = sm.add_constant(X)  # Add intercept term
        
        # Prepare dependent variable
        y = df[asset]
        
        # Ensure no missing values in the regression data
        valid_data = ~y.isna() & X.notna().all(axis=1)
        X_valid = X[valid_data]
        y_valid = y[valid_data]
        
        # Run OLS regression
        model = sm.OLS(y_valid, X_valid).fit()
        results[asset] = model
        
        # Print summary
        print(f"Regression Results for {asset}:")
        print(model.summary())
        print("\n" + "="*80 + "\n")
    
    return results

# Main execution
if __name__ == "__main__":
    # Load data
    file_path = 'data/VC0.csv'
    df = load_and_prepare_data(file_path)
    
    # Define dependent variables (index and ETFs)
    dependent_vars = [
        'S&P500', 'NASDAQ', 'SPY', 'QQQ', 
        'Tech_ETF', 'Financials_ETF', 'Energy_ETF','VIX'
    ]
    
    # Run regressions
    regression_results = run_regressions(df, dependent_vars)
# Out:
# Regression Results for S&P500:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 S&P500   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2088
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.890
# Time:                        18:21:12   Log-Likelihood:                -379.30
# No. Observations:                 242   AIC:                             766.6
# Df Residuals:                     238   BIC:                             780.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.1091      0.633     -0.172      0.863      -1.357       1.138
# sentiment_lag1     0.0333      0.821      0.041      0.968      -1.583       1.650
# yield              0.1365      0.414      0.330      0.742      -0.679       0.952
# binary             0.6196      0.838      0.740      0.460      -1.030       2.270
# ==============================================================================
# Omnibus:                        7.878   Durbin-Watson:                   2.158
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                9.433
# Skew:                          -0.279   Prob(JB):                      0.00895
# Kurtosis:                       3.790   Cond. No.                         20.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for NASDAQ:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 NASDAQ   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2226
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.881
# Time:                        18:21:12   Log-Likelihood:                -295.62
# No. Observations:                 242   AIC:                             599.2
# Df Residuals:                     238   BIC:                             613.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.1860      0.448     -0.415      0.678      -1.069       0.697
# sentiment_lag1     0.1275      0.581      0.220      0.826      -1.016       1.271
# yield              0.1762      0.293      0.602      0.548      -0.401       0.753
# binary             0.3239      0.593      0.547      0.585      -0.844       1.492
# ==============================================================================
# Omnibus:                        7.523   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.023   Jarque-Bera (JB):                7.831
# Skew:                          -0.332   Prob(JB):                       0.0199
# Kurtosis:                       3.580   Cond. No.                         20.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for SPY:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SPY   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.1908
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.903
# Time:                        18:21:12   Log-Likelihood:                -492.64
# No. Observations:                 242   AIC:                             993.3
# Df Residuals:                     238   BIC:                             1007.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.8497      1.011      0.840      0.402      -1.143       2.842
# sentiment_lag1     0.0996      1.311      0.076      0.940      -2.482       2.681
# yield             -0.4678      0.661     -0.708      0.480      -1.770       0.835
# binary             0.2334      1.338      0.174      0.862      -2.402       2.869
# ==============================================================================
# Omnibus:                        1.728   Durbin-Watson:                   1.976
# Prob(Omnibus):                  0.421   Jarque-Bera (JB):                1.472
# Skew:                           0.009   Prob(JB):                        0.479
# Kurtosis:                       2.618   Cond. No.                         20.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for QQQ:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    QQQ   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.004
# Method:                 Least Squares   F-statistic:                    0.6529
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.582
# Time:                        18:21:12   Log-Likelihood:                -383.80
# No. Observations:                 242   AIC:                             775.6
# Df Residuals:                     238   BIC:                             789.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.1844      0.645     -0.286      0.775      -1.455       1.086
# sentiment_lag1     0.7378      0.836      0.883      0.378      -0.909       2.384
# yield              0.0966      0.422      0.229      0.819      -0.734       0.927
# binary             0.8517      0.853      0.998      0.319      -0.829       2.533
# ==============================================================================
# Omnibus:                        2.008   Durbin-Watson:                   2.051
# Prob(Omnibus):                  0.366   Jarque-Bera (JB):                1.884
# Skew:                          -0.010   Prob(JB):                        0.390
# Kurtosis:                       3.432   Cond. No.                         20.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for Tech_ETF:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Tech_ETF   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.1259
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.945
# Time:                        18:21:12   Log-Likelihood:                -393.20
# No. Observations:                 242   AIC:                             794.4
# Df Residuals:                     238   BIC:                             808.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.1235      0.671     -0.184      0.854      -1.445       1.198
# sentiment_lag1    -0.0471      0.869     -0.054      0.957      -1.759       1.665
# yield              0.1722      0.438      0.393      0.695      -0.691       1.036
# binary             0.4486      0.887      0.506      0.614      -1.299       2.196
# ==============================================================================
# Omnibus:                        1.496   Durbin-Watson:                   2.221
# Prob(Omnibus):                  0.473   Jarque-Bera (JB):                1.172
# Skew:                          -0.127   Prob(JB):                        0.556
# Kurtosis:                       3.228   Cond. No.                         20.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for Financials_ETF:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Financials_ETF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2173
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.884
# Time:                        18:21:12   Log-Likelihood:                -298.08
# No. Observations:                 242   AIC:                             604.2
# Df Residuals:                     238   BIC:                             618.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.2037      0.453     -0.450      0.653      -1.096       0.688
# sentiment_lag1     0.1477      0.587      0.252      0.801      -1.008       1.303
# yield              0.1823      0.296      0.616      0.538      -0.401       0.765
# binary             0.2977      0.599      0.497      0.619      -0.882       1.477
# ==============================================================================
# Omnibus:                        7.783   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):                8.159
# Skew:                          -0.338   Prob(JB):                       0.0169
# Kurtosis:                       3.594   Cond. No.                         20.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for Energy_ETF:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Energy_ETF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2009
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.896
# Time:                        18:21:12   Log-Likelihood:                -376.81
# No. Observations:                 242   AIC:                             761.6
# Df Residuals:                     238   BIC:                             775.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.1090      0.627      0.174      0.862      -1.126       1.344
# sentiment_lag1     0.0110      0.812      0.014      0.989      -1.589       1.611
# yield             -0.0245      0.410     -0.060      0.952      -0.832       0.783
# binary             0.6305      0.829      0.761      0.448      -1.003       2.264
# ==============================================================================
# Omnibus:                        7.902   Durbin-Watson:                   2.131
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                8.808
# Skew:                          -0.312   Prob(JB):                       0.0122
# Kurtosis:                       3.696   Cond. No.                         20.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for VIX:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    VIX   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.2987
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.826
# Time:                        18:21:12   Log-Likelihood:                -894.21
# No. Observations:                 242   AIC:                             1796.
# Df Residuals:                     238   BIC:                             1810.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              5.1098      5.316      0.961      0.337      -5.364      15.583
# sentiment_lag1    -1.0835      6.889     -0.157      0.875     -14.654      12.487
# yield             -3.1239      3.475     -0.899      0.370      -9.969       3.722
# binary            -2.3475      7.032     -0.334      0.739     -16.200      11.505
# ==============================================================================
# Omnibus:                      126.614   Durbin-Watson:                   2.227
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              982.914
# Skew:                           1.922   Prob(JB):                    3.65e-214
# Kurtosis:                      12.094   Cond. No.                         20.9
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# Load and preprocess data
def load_and_prepare_data(file_path):
    # Load data with error handling for missing values
    df = pd.read_csv(file_path, 
                    parse_dates=['date'], 
                    na_values=['#N/A', 'N/A', 'NaN'])
    
    # Create lagged sentiment score (t-1)
    df['sentiment_lag1'] = df['sentiment_score'].shift(1)
    
    # Drop missing values
    df = df.dropna(subset=['sentiment_lag1', 'yield', 'binary'])
    
    return df

# Run regression for multiple assets
def run_regressions(df, dependent_vars):
    results = {}
    
    for asset in dependent_vars:
        # Prepare independent variables
        X = df[['sentiment_lag1', 'yield', 'binary']]
        X = sm.add_constant(X)  # Add intercept term
        
        # Prepare dependent variable
        y = df[asset]
        
        # Ensure no missing values in the regression data
        valid_data = ~y.isna() & X.notna().all(axis=1)
        X_valid = X[valid_data]
        y_valid = y[valid_data]
        
        # Run OLS regression
        model = sm.OLS(y_valid, X_valid).fit()
        results[asset] = model
        
        # Print summary
        print(f"Regression Results for {asset}:")
        print(model.summary())
        print("\n" + "="*80 + "\n")
    
    return results

# Main execution
if __name__ == "__main__":
    # Load data
    file_path = 'data/VC1.csv'
    df = load_and_prepare_data(file_path)
    
    # Define dependent variables (index and ETFs)
    dependent_vars = [
        'S&P500', 'NASDAQ', 'SPY', 'QQQ', 
        'Tech_ETF', 'Financials_ETF', 'Energy_ETF','VIX'
    ]
    
    # Run regressions
    regression_results = run_regressions(df, dependent_vars)
# Out:
# Regression Results for S&P500:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 S&P500   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2417
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.867
# Time:                        18:21:22   Log-Likelihood:                -377.99
# No. Observations:                 241   AIC:                             764.0
# Df Residuals:                     237   BIC:                             777.9
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.0692      0.827      0.084      0.933      -1.561       1.699
# sentiment_lag1    -0.4228      1.359     -0.311      0.756      -3.101       2.255
# yield              0.1356      0.415      0.327      0.744      -0.682       0.953
# binary             0.6213      0.835      0.744      0.458      -1.024       2.266
# ==============================================================================
# Omnibus:                        7.988   Durbin-Watson:                   2.161
# Prob(Omnibus):                  0.018   Jarque-Bera (JB):                9.553
# Skew:                          -0.284   Prob(JB):                      0.00842
# Kurtosis:                       3.792   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for NASDAQ:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 NASDAQ   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.2506
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.861
# Time:                        18:21:22   Log-Likelihood:                -294.76
# No. Observations:                 241   AIC:                             597.5
# Df Residuals:                     237   BIC:                             611.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.2998      0.586     -0.512      0.609      -1.454       0.854
# sentiment_lag1     0.3392      0.962      0.352      0.725      -1.557       2.235
# yield              0.1827      0.294      0.622      0.534      -0.396       0.761
# binary             0.3343      0.591      0.565      0.572      -0.831       1.499
# ==============================================================================
# Omnibus:                        7.451   Durbin-Watson:                   2.063
# Prob(Omnibus):                  0.024   Jarque-Bera (JB):                7.701
# Skew:                          -0.333   Prob(JB):                       0.0213
# Kurtosis:                       3.568   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for SPY:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SPY   R-squared:                       0.019
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.522
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.209
# Time:                        18:21:22   Log-Likelihood:                -489.09
# No. Observations:                 241   AIC:                             986.2
# Df Residuals:                     237   BIC:                             1000.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.9225      1.312     -0.703      0.483      -3.507       1.662
# sentiment_lag1     4.3060      2.156      1.998      0.047       0.060       8.553
# yield             -0.4020      0.658     -0.611      0.542      -1.698       0.894
# binary             0.2377      1.324      0.179      0.858      -2.371       2.846
# ==============================================================================
# Omnibus:                        1.710   Durbin-Watson:                   1.973
# Prob(Omnibus):                  0.425   Jarque-Bera (JB):                1.476
# Skew:                          -0.033   Prob(JB):                        0.478
# Kurtosis:                       2.622   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for QQQ:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    QQQ   R-squared:                       0.008
# Model:                            OLS   Adj. R-squared:                 -0.005
# Method:                 Least Squares   F-statistic:                    0.6353
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.593
# Time:                        18:21:22   Log-Likelihood:                -382.70
# No. Observations:                 241   AIC:                             773.4
# Df Residuals:                     237   BIC:                             787.3
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.5041      0.844     -0.597      0.551      -2.166       1.158
# sentiment_lag1     1.1857      1.386      0.855      0.393      -1.545       3.917
# yield              0.1064      0.423      0.252      0.802      -0.727       0.940
# binary             0.9169      0.852      1.077      0.283      -0.761       2.595
# ==============================================================================
# Omnibus:                        2.188   Durbin-Watson:                   2.043
# Prob(Omnibus):                  0.335   Jarque-Bera (JB):                2.127
# Skew:                           0.002   Prob(JB):                        0.345
# Kurtosis:                       3.460   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for Tech_ETF:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Tech_ETF   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.3610
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.781
# Time:                        18:21:22   Log-Likelihood:                -391.60
# No. Observations:                 241   AIC:                             791.2
# Df Residuals:                     237   BIC:                             805.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.3626      0.876      0.414      0.679      -1.362       2.087
# sentiment_lag1    -1.2045      1.438     -0.837      0.403      -4.038       1.629
# yield              0.1592      0.439      0.363      0.717      -0.705       1.024
# binary             0.4441      0.884      0.503      0.616      -1.297       2.185
# ==============================================================================
# Omnibus:                        1.613   Durbin-Watson:                   2.223
# Prob(Omnibus):                  0.447   Jarque-Bera (JB):                1.283
# Skew:                          -0.130   Prob(JB):                        0.527
# Kurtosis:                       3.245   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for Financials_ETF:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Financials_ETF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2216
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.881
# Time:                        18:21:22   Log-Likelihood:                -297.25
# No. Observations:                 241   AIC:                             602.5
# Df Residuals:                     237   BIC:                             616.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.2769      0.592     -0.468      0.640      -1.443       0.889
# sentiment_lag1     0.2532      0.972      0.260      0.795      -1.662       2.169
# yield              0.1872      0.297      0.631      0.529      -0.397       0.772
# binary             0.3100      0.597      0.519      0.604      -0.867       1.487
# ==============================================================================
# Omnibus:                        7.797   Durbin-Watson:                   2.085
# Prob(Omnibus):                  0.020   Jarque-Bera (JB):                8.139
# Skew:                          -0.341   Prob(JB):                       0.0171
# Kurtosis:                       3.587   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for Energy_ETF:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Energy_ETF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2146
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.886
# Time:                        18:21:22   Log-Likelihood:                -375.55
# No. Observations:                 241   AIC:                             759.1
# Df Residuals:                     237   BIC:                             773.0
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.2313      0.819      0.282      0.778      -1.382       1.845
# sentiment_lag1    -0.3005      1.346     -0.223      0.823      -2.952       2.351
# yield             -0.0234      0.411     -0.057      0.955      -0.832       0.786
# binary             0.6301      0.827      0.762      0.447      -0.999       2.259
# ==============================================================================
# Omnibus:                        8.016   Durbin-Watson:                   2.133
# Prob(Omnibus):                  0.018   Jarque-Bera (JB):                8.907
# Skew:                          -0.318   Prob(JB):                       0.0116
# Kurtosis:                       3.695   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for VIX:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    VIX   R-squared:                       0.007
# Model:                            OLS   Adj. R-squared:                 -0.006
# Method:                 Least Squares   F-statistic:                    0.5258
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.665
# Time:                        18:21:22   Log-Likelihood:                -890.66
# No. Observations:                 241   AIC:                             1789.
# Df Residuals:                     237   BIC:                             1803.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.8286      6.944      0.119      0.905     -12.851      14.508
# sentiment_lag1     9.6183     11.408      0.843      0.400     -12.856      32.093
# yield             -2.9481      3.481     -0.847      0.398      -9.806       3.910
# binary            -2.4597      7.008     -0.351      0.726     -16.266      11.347
# ==============================================================================
# Omnibus:                      128.883   Durbin-Watson:                   2.214
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1035.797
# Skew:                           1.961   Prob(JB):                    1.20e-225
# Kurtosis:                      12.368   Cond. No.                         35.8
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# Load and preprocess data
def load_and_prepare_data(file_path):
    # Load data with error handling for missing values
    df = pd.read_csv(file_path, 
                    parse_dates=['date'], 
                    na_values=['#N/A', 'N/A', 'NaN'])
    
    # Create lagged sentiment score (t-1)
    df['sentiment_lag1'] = df['sentiment_score'].shift(1)
    
    # Drop missing values
    df = df.dropna(subset=['sentiment_lag1', 'yield', 'binary'])
    
    return df

# Run regression for multiple assets
def run_regressions(df, dependent_vars):
    results = {}
    
    for asset in dependent_vars:
        # Prepare independent variables
        X = df[['sentiment_lag1', 'yield', 'binary']]
        X = sm.add_constant(X)  # Add intercept term
        
        # Prepare dependent variable
        y = df[asset]
        
        # Ensure no missing values in the regression data
        valid_data = ~y.isna() & X.notna().all(axis=1)
        X_valid = X[valid_data]
        y_valid = y[valid_data]
        
        # Run OLS regression
        model = sm.OLS(y_valid, X_valid).fit()
        results[asset] = model
        
        # Print summary
        print(f"Regression Results for {asset}:")
        print(model.summary())
        print("\n" + "="*80 + "\n")
    
    return results

# Main execution
if __name__ == "__main__":
    # Load data
    file_path = 'data/FC0.csv'
    df = load_and_prepare_data(file_path)
    
    # Define dependent variables (index and ETFs)
    dependent_vars = [
        'S&P500', 'NASDAQ', 'SPY', 'QQQ', 
        'Tech_ETF', 'Financials_ETF', 'Energy_ETF','VIX'
    ]
    
    # Run regressions
    regression_results = run_regressions(df, dependent_vars)
# Out:
# Regression Results for S&P500:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 S&P500   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2094
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.890
# Time:                        18:21:28   Log-Likelihood:                -379.30
# No. Observations:                 242   AIC:                             766.6
# Df Residuals:                     238   BIC:                             780.6
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.1019      0.602     -0.169      0.866      -1.287       1.084
# sentiment_lag1    -0.0706      1.207     -0.059      0.953      -2.448       2.306
# yield              0.1389      0.417      0.333      0.739      -0.682       0.960
# binary             0.6250      0.835      0.748      0.455      -1.020       2.270
# ==============================================================================
# Omnibus:                        7.901   Durbin-Watson:                   2.158
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                9.464
# Skew:                          -0.280   Prob(JB):                      0.00881
# Kurtosis:                       3.791   Cond. No.                         28.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for NASDAQ:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 NASDAQ   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2252
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.879
# Time:                        18:21:28   Log-Likelihood:                -295.62
# No. Observations:                 242   AIC:                             599.2
# Df Residuals:                     238   BIC:                             613.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.1577      0.426     -0.370      0.711      -0.997       0.681
# sentiment_lag1    -0.2023      0.854     -0.237      0.813      -1.884       1.480
# yield              0.1827      0.295      0.619      0.536      -0.398       0.764
# binary             0.3423      0.591      0.579      0.563      -0.822       1.507
# ==============================================================================
# Omnibus:                        7.617   Durbin-Watson:                   2.057
# Prob(Omnibus):                  0.022   Jarque-Bera (JB):                7.950
# Skew:                          -0.334   Prob(JB):                       0.0188
# Kurtosis:                       3.585   Cond. No.                         28.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for SPY:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SPY   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.008
# Method:                 Least Squares   F-statistic:                    0.3543
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.786
# Time:                        18:21:28   Log-Likelihood:                -492.39
# No. Observations:                 242   AIC:                             992.8
# Df Residuals:                     238   BIC:                             1007.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.8574      0.960      0.893      0.373      -1.034       2.749
# sentiment_lag1    -1.3548      1.925     -0.704      0.482      -5.148       2.438
# yield             -0.4128      0.665     -0.621      0.535      -1.723       0.897
# binary             0.2877      1.333      0.216      0.829      -2.338       2.913
# ==============================================================================
# Omnibus:                        1.736   Durbin-Watson:                   1.963
# Prob(Omnibus):                  0.420   Jarque-Bera (JB):                1.479
# Skew:                           0.016   Prob(JB):                        0.477
# Kurtosis:                       2.618   Cond. No.                         28.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for QQQ:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    QQQ   R-squared:                       0.005
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.4383
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.726
# Time:                        18:21:28   Log-Likelihood:                -384.13
# No. Observations:                 242   AIC:                             776.3
# Df Residuals:                     238   BIC:                             790.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.0122      0.614     -0.020      0.984      -1.222       1.197
# sentiment_lag1    -0.4577      1.231     -0.372      0.710      -2.883       1.967
# yield              0.1042      0.425      0.245      0.807      -0.733       0.942
# binary             0.9343      0.852      1.097      0.274      -0.744       2.613
# ==============================================================================
# Omnibus:                        2.056   Durbin-Watson:                   2.022
# Prob(Omnibus):                  0.358   Jarque-Bera (JB):                1.949
# Skew:                          -0.006   Prob(JB):                        0.377
# Kurtosis:                       3.439   Cond. No.                         28.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for Tech_ETF:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Tech_ETF   R-squared:                       0.002
# Model:                            OLS   Adj. R-squared:                 -0.011
# Method:                 Least Squares   F-statistic:                    0.1250
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.945
# Time:                        18:21:28   Log-Likelihood:                -393.20
# No. Observations:                 242   AIC:                             794.4
# Df Residuals:                     238   BIC:                             808.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.1347      0.637     -0.211      0.833      -1.390       1.121
# sentiment_lag1     0.0106      1.278      0.008      0.993      -2.507       2.528
# yield              0.1725      0.441      0.391      0.696      -0.697       1.042
# binary             0.4439      0.885      0.502      0.616      -1.299       2.186
# ==============================================================================
# Omnibus:                        1.494   Durbin-Watson:                   2.221
# Prob(Omnibus):                  0.474   Jarque-Bera (JB):                1.170
# Skew:                          -0.126   Prob(JB):                        0.557
# Kurtosis:                       3.228   Cond. No.                         28.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for Financials_ETF:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Financials_ETF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2143
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.886
# Time:                        18:21:28   Log-Likelihood:                -298.08
# No. Observations:                 242   AIC:                             604.2
# Df Residuals:                     238   BIC:                             618.1
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.1706      0.430     -0.396      0.692      -1.018       0.677
# sentiment_lag1    -0.2014      0.863     -0.233      0.816      -1.901       1.498
# yield              0.1884      0.298      0.632      0.528      -0.399       0.775
# binary             0.3179      0.597      0.533      0.595      -0.858       1.494
# ==============================================================================
# Omnibus:                        7.890   Durbin-Watson:                   2.079
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                8.294
# Skew:                          -0.340   Prob(JB):                       0.0158
# Kurtosis:                       3.599   Cond. No.                         28.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for Energy_ETF:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Energy_ETF   R-squared:                       0.003
# Model:                            OLS   Adj. R-squared:                 -0.010
# Method:                 Least Squares   F-statistic:                    0.2134
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.887
# Time:                        18:21:28   Log-Likelihood:                -376.80
# No. Observations:                 242   AIC:                             761.6
# Df Residuals:                     238   BIC:                             775.5
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.1089      0.596      0.183      0.855      -1.064       1.282
# sentiment_lag1    -0.2319      1.194     -0.194      0.846      -2.585       2.121
# yield             -0.0150      0.412     -0.036      0.971      -0.828       0.798
# binary             0.6393      0.827      0.773      0.440      -0.989       2.268
# ==============================================================================
# Omnibus:                        7.971   Durbin-Watson:                   2.130
# Prob(Omnibus):                  0.019   Jarque-Bera (JB):                8.912
# Skew:                          -0.313   Prob(JB):                       0.0116
# Kurtosis:                       3.702   Cond. No.                         28.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for VIX:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    VIX   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9033
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.440
# Time:                        18:21:28   Log-Likelihood:                -893.29
# No. Observations:                 242   AIC:                             1795.
# Df Residuals:                     238   BIC:                             1809.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              5.0126      5.033      0.996      0.320      -4.903      14.928
# sentiment_lag1    13.6601     10.093      1.353      0.177      -6.222      33.542
# yield             -3.6771      3.486     -1.055      0.293     -10.544       3.190
# binary            -2.9025      6.985     -0.416      0.678     -16.663      10.858
# ==============================================================================
# Omnibus:                      128.715   Durbin-Watson:                   2.207
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1014.221
# Skew:                           1.957   Prob(JB):                    5.82e-221
# Kurtosis:                      12.234   Cond. No.                         28.3
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm

# Load and preprocess data
def load_and_prepare_data(file_path):
    # Load data with error handling for missing values
    df = pd.read_csv(file_path, 
                    parse_dates=['date'], 
                    na_values=['#N/A', 'N/A', 'NaN'])
    
    # Create lagged sentiment score (t-1)
    df['sentiment_lag1'] = df['sentiment_score'].shift(1)
    
    # Drop missing values
    df = df.dropna(subset=['sentiment_lag1', 'yield', 'binary'])
    
    return df

# Run regression for multiple assets
def run_regressions(df, dependent_vars):
    results = {}
    
    for asset in dependent_vars:
        # Prepare independent variables
        X = df[['sentiment_lag1', 'yield', 'binary']]
        X = sm.add_constant(X)  # Add intercept term
        
        # Prepare dependent variable
        y = df[asset]
        
        # Ensure no missing values in the regression data
        valid_data = ~y.isna() & X.notna().all(axis=1)
        X_valid = X[valid_data]
        y_valid = y[valid_data]
        
        # Run OLS regression
        model = sm.OLS(y_valid, X_valid).fit()
        results[asset] = model
        
        # Print summary
        print(f"Regression Results for {asset}:")
        print(model.summary())
        print("\n" + "="*80 + "\n")
    
    return results

# Main execution
if __name__ == "__main__":
    # Load data
    file_path = 'data/FC1.csv'
    df = load_and_prepare_data(file_path)
    
    # Define dependent variables (index and ETFs)
    dependent_vars = [
        'S&P500', 'NASDAQ', 'SPY', 'QQQ', 
        'Tech_ETF', 'Financials_ETF', 'Energy_ETF','VIX'
    ]
    
    # Run regressions
    regression_results = run_regressions(df, dependent_vars)
# Out:
# Regression Results for S&P500:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 S&P500   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.4523
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.716
# Time:                        18:21:35   Log-Likelihood:                -378.93
# No. Observations:                 242   AIC:                             765.9
# Df Residuals:                     238   BIC:                             779.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.3852      0.687     -0.561      0.575      -1.738       0.967
# sentiment_lag1     0.8767      1.026      0.855      0.394      -1.144       2.898
# yield              0.1508      0.413      0.365      0.716      -0.664       0.965
# binary             0.6900      0.837      0.825      0.410      -0.958       2.338
# ==============================================================================
# Omnibus:                        7.166   Durbin-Watson:                   2.173
# Prob(Omnibus):                  0.028   Jarque-Bera (JB):                8.833
# Skew:                          -0.240   Prob(JB):                       0.0121
# Kurtosis:                       3.804   Cond. No.                         26.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for NASDAQ:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                 NASDAQ   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.002
# Method:                 Least Squares   F-statistic:                    0.8776
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.453
# Time:                        18:21:35   Log-Likelihood:                -294.63
# No. Observations:                 242   AIC:                             597.3
# Df Residuals:                     238   BIC:                             611.2
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.4878      0.485     -1.007      0.315      -1.442       0.467
# sentiment_lag1     1.0261      0.724      1.417      0.158      -0.400       2.453
# yield              0.1916      0.292      0.656      0.512      -0.383       0.766
# binary             0.4145      0.591      0.702      0.483      -0.749       1.578
# ==============================================================================
# Omnibus:                        5.157   Durbin-Watson:                   2.100
# Prob(Omnibus):                  0.076   Jarque-Bera (JB):                5.220
# Skew:                          -0.246   Prob(JB):                       0.0735
# Kurtosis:                       3.526   Cond. No.                         26.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for SPY:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    SPY   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.4710
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.703
# Time:                        18:21:35   Log-Likelihood:                -492.21
# No. Observations:                 242   AIC:                             992.4
# Df Residuals:                     238   BIC:                             1006.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const              0.3858      1.096      0.352      0.725      -1.774       2.546
# sentiment_lag1     1.5055      1.638      0.919      0.359      -1.722       4.733
# yield             -0.4439      0.660     -0.672      0.502      -1.745       0.857
# binary             0.3582      1.336      0.268      0.789      -2.274       2.990
# ==============================================================================
# Omnibus:                        1.741   Durbin-Watson:                   1.994
# Prob(Omnibus):                  0.419   Jarque-Bera (JB):                1.482
# Skew:                           0.015   Prob(JB):                        0.477
# Kurtosis:                       2.618   Cond. No.                         26.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for QQQ:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    QQQ   R-squared:                       0.011
# Model:                            OLS   Adj. R-squared:                 -0.001
# Method:                 Least Squares   F-statistic:                    0.9129
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.435
# Time:                        18:21:35   Log-Likelihood:                -383.41
# No. Observations:                 242   AIC:                             774.8
# Df Residuals:                     238   BIC:                             788.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.4291      0.699     -0.613      0.540      -1.807       0.949
# sentiment_lag1     1.3032      1.045      1.247      0.214      -0.755       3.362
# yield              0.1071      0.421      0.254      0.800      -0.723       0.937
# binary             1.0192      0.852      1.196      0.233      -0.660       2.698
# ==============================================================================
# Omnibus:                        2.057   Durbin-Watson:                   2.080
# Prob(Omnibus):                  0.358   Jarque-Bera (JB):                1.939
# Skew:                           0.026   Prob(JB):                        0.379
# Kurtosis:                       3.435   Cond. No.                         26.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for Tech_ETF:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               Tech_ETF   R-squared:                       0.004
# Model:                            OLS   Adj. R-squared:                 -0.009
# Method:                 Least Squares   F-statistic:                    0.3133
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.816
# Time:                        18:21:35   Log-Likelihood:                -392.92
# No. Observations:                 242   AIC:                             793.8
# Df Residuals:                     238   BIC:                             807.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.3994      0.727     -0.549      0.583      -1.832       1.034
# sentiment_lag1     0.8165      1.087      0.751      0.453      -1.325       2.958
# yield              0.1867      0.438      0.426      0.670      -0.676       1.050
# binary             0.5070      0.886      0.572      0.568      -1.239       2.253
# ==============================================================================
# Omnibus:                        1.293   Durbin-Watson:                   2.232
# Prob(Omnibus):                  0.524   Jarque-Bera (JB):                0.980
# Skew:                          -0.091   Prob(JB):                        0.613
# Kurtosis:                       3.253   Cond. No.                         26.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for Financials_ETF:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:         Financials_ETF   R-squared:                       0.010
# Model:                            OLS   Adj. R-squared:                 -0.003
# Method:                 Least Squares   F-statistic:                    0.7975
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.496
# Time:                        18:21:35   Log-Likelihood:                -297.20
# No. Observations:                 242   AIC:                             602.4
# Df Residuals:                     238   BIC:                             616.4
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.4863      0.490     -0.993      0.322      -1.451       0.479
# sentiment_lag1     0.9818      0.732      1.342      0.181      -0.460       2.423
# yield              0.1965      0.295      0.666      0.506      -0.384       0.778
# binary             0.3867      0.597      0.648      0.518      -0.789       1.562
# ==============================================================================
# Omnibus:                        5.563   Durbin-Watson:                   2.120
# Prob(Omnibus):                  0.062   Jarque-Bera (JB):                5.707
# Skew:                          -0.258   Prob(JB):                       0.0577
# Kurtosis:                       3.548   Cond. No.                         26.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for Energy_ETF:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:             Energy_ETF   R-squared:                       0.006
# Model:                            OLS   Adj. R-squared:                 -0.007
# Method:                 Least Squares   F-statistic:                    0.4743
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.700
# Time:                        18:21:35   Log-Likelihood:                -376.40
# No. Observations:                 242   AIC:                             760.8
# Df Residuals:                     238   BIC:                             774.8
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.1859      0.679     -0.274      0.785      -1.524       1.152
# sentiment_lag1     0.9184      1.015      0.905      0.367      -1.081       2.918
# yield             -0.0091      0.409     -0.022      0.982      -0.815       0.797
# binary             0.7021      0.828      0.848      0.397      -0.929       2.333
# ==============================================================================
# Omnibus:                        6.861   Durbin-Watson:                   2.150
# Prob(Omnibus):                  0.032   Jarque-Bera (JB):                7.812
# Skew:                          -0.263   Prob(JB):                       0.0201
# Kurtosis:                       3.706   Cond. No.                         26.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
#
# Regression Results for VIX:
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                    VIX   R-squared:                       0.018
# Model:                            OLS   Adj. R-squared:                  0.006
# Method:                 Least Squares   F-statistic:                     1.464
# Date:                Wed, 12 Mar 2025   Prob (F-statistic):              0.225
# Time:                        18:21:35   Log-Likelihood:                -892.45
# No. Observations:                 242   AIC:                             1793.
# Df Residuals:                     238   BIC:                             1807.
# Df Model:                           3
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             10.0464      5.731      1.753      0.081      -1.244      21.336
# sentiment_lag1   -16.0396      8.564     -1.873      0.062     -32.910       0.831
# yield             -3.3778      3.451     -0.979      0.329     -10.177       3.421
# binary            -3.6794      6.984     -0.527      0.599     -17.438      10.079
# ==============================================================================
# Omnibus:                      116.167   Durbin-Watson:                   2.271
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              824.860
# Skew:                           1.754   Prob(JB):                    7.66e-180
# Kurtosis:                      11.337   Cond. No.                         26.6
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
#
# ================================================================================
